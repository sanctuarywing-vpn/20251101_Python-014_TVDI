# %%
print(5+8)
print(90-10)
print(4*7)
print(7/2)
print(7//2)
print(7%3)
print(3**4)
print(99**99)
# Out:
# 13
# 80
# 28
# 3.5
# 3
# 1
# 81
# 369729637649726772657187905628805440595668764281741102430259972423552570455277523421410650010128232727940978889548326540119429996769494359451621570193644014418071060667659301384999779999159200499899

# %% [markdown]
# 若未使用 print() 標註 則只會顯示最後一行數值

# %%
# '#' 後面的內容為註解，不會被執行
# python的基本資料型別
# int 整數
5
# float 浮點數
5.0
# str 字串 (不計算))
"5"
'5'

# bool 布林值
ture # 真
false # 假
